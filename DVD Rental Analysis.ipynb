# %% [markdown]
# # DVD Rental Analysis<br>
# ***

# %% [markdown]
# The significance of customer and film analysis in DVD rental lies in its ability to optimize business strategies and cultivate customer loyalty. By comprehending rental patterns and preferences, the rental service can customize marketing campaigns, provide popular film categories, and adapt to seasonal variations. Analyzing language and cultural preferences further enables tailored film selections for diverse customers. Moreover, competitor analysis aids in benchmarking and identifying market opportunities. In essence, data-driven insights empower the rental service to make informed decisions, enhance customer experiences, and foster revenue growth within the dynamic DVD rental market.

# %% [markdown]
# The DVD rental database has many objects, including:
# - 15 tables<br>
# - 1 trigger<br>
# - 7 views<br>
# - 8 functions<br>
# - 1 domain<br>
# - 13 sequences<br>

# %% [markdown]
# ![dvd-rental-sample-database-diagram.png](attachment:dvd-rental-sample-database-diagram.png)

# %% [markdown]
# There are 15 tables in the DVD Rental database:
# - __actor__ : stores actors data including first name and last name<br>
# - __film__ : stores film data such as title, release year, length, rating, etc<br>
# - __film_actor__ : stores the relationships between films and actors<br>
# - __category__ : stores film’s categories data<br>
# - __film_category__ : stores the relationships between films and categories<br>
# - __store__ : contains the store data including manager staff and address<br>
# - __inventory__ : stores inventory data<br>
# - __rental__ : stores rental data<br>
# - __payment__ : stores customer’s payments<br>
# - __staff__ : stores staff data<br>
# - __customer__ : stores customer data<br>
# - __address__ : stores address data for staff and customers<br>
# - __city__ : stores city names<br>
# - __country__ : stores country names<br>

# %% [markdown]
# # Customer Analysis

# %% [markdown]
# ## 1. How many distinct customers are in our database, and what are their contact details?

# %%
# %%sql
# SELECT COUNT(DISTINCT(customer_id)) AS total_distinct_customer
# FROM customer;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(599,)]

# %% [markdown]
# There are 599 unique customers in this dataset. Their full name associated with phone and email information are listed as below:

# %%
# %%sql
# SELECT CONCAT(first_name, ' ', last_name) AS full_name, phone, email
# FROM customer AS c
# INNER JOIN address AS a ON c.address_id = a.address_id;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 599 rows affected.
# [('Jared Ely', '35533115997', 'jared.ely@sakilacustomer.org'),
#  ('Mary Smith', '28303384290', 'mary.smith@sakilacustomer.org'),
#  ('Patricia Johnson', '838635286649', 'patricia.johnson@sakilacustomer.org'),
#  ('Linda Williams', '448477190408', 'linda.williams@sakilacustomer.org'),
#  ('Barbara Jones', '705814003527', 'barbara.jones@sakilacustomer.org'),
#  ('Elizabeth Brown', '10655648674', 'elizabeth.brown@sakilacustomer.org'),
#  ('Jennifer Davis', '860452626434', 'jennifer.davis@sakilacustomer.org'),
#  ('Maria Miller', '716571220373', 'maria.miller@sakilacustomer.org'),
#  ('Susan Wilson', '657282285970', 'susan.wilson@sakilacustomer.org'),
#  ('Margaret Moore', '380657522649', 'margaret.moore@sakilacustomer.org'),
#  ('Dorothy Taylor', '648856936185', 'dorothy.taylor@sakilacustomer.org'),
#  ('Lisa Anderson', '635297277345', 'lisa.anderson@sakilacustomer.org'),
#  ('Nancy Thomas', '465887807014', 'nancy.thomas@sakilacustomer.org'),
#  ('Karen Jackson', '695479687538', 'karen.jackson@sakilacustomer.org'),
#  ('Betty White', '517338314235', 'betty.white@sakilacustomer.org'),
#  ('Heather Morris', '697760867968', 'heather.morris@sakilacustomer.org'),
#  ('Teresa Rogers', '920811325222', 'teresa.rogers@sakilacustomer.org'),
#  ('Doris Reed', '499352017190', 'doris.reed@sakilacustomer.org'),
#  ('Gloria Cook', '347487831378', 'gloria.cook@sakilacustomer.org'),
#  ('Evelyn Morgan', '889318963672', 'evelyn.morgan@sakilacustomer.org'),
#  ('Jean Bell', '212869228936', 'jean.bell@sakilacustomer.org'),
#  ('Cheryl Murphy', '800024380485', 'cheryl.murphy@sakilacustomer.org'),
#  ('Mildred Bailey', '250767749542', 'mildred.bailey@sakilacustomer.org'),
#  ('Katherine Rivera', '1395251317', 'katherine.rivera@sakilacustomer.org'),
#  ('Joan Cooper', '914090181665', 'joan.cooper@sakilacustomer.org'),
#  ('Ashley Richardson', '491001136577', 'ashley.richardson@sakilacustomer.org'),
#  ('Judith Cox', '333489324603', 'judith.cox@sakilacustomer.org'),
#  ('Rose Howard', '409983924481', 'rose.howard@sakilacustomer.org'),
#  ('Janice Ward', '663449333709', 'janice.ward@sakilacustomer.org'),
#  ('Kelly Torres', '947233365992', 'kelly.torres@sakilacustomer.org'),
#  ('Nicole Peterson', '990214419142', 'nicole.peterson@sakilacustomer.org'),
#  ('Judy Gray', '107137400143', 'judy.gray@sakilacustomer.org'),
#  ('Christina Ramirez', '407733804223', 'christina.ramirez@sakilacustomer.org'),
#  ('Kathy James', '565018274456', 'kathy.james@sakilacustomer.org'),
#  ('Theresa Watson', '255800440636', 'theresa.watson@sakilacustomer.org'),
#  ('Beverly Brooks', '427454485876', 'beverly.brooks@sakilacustomer.org'),
#  ('Denise Kelly', '241832790687', 'denise.kelly@sakilacustomer.org'),
#  ('Tammy Sanders', '251164340471', 'tammy.sanders@sakilacustomer.org'),
#  ('Irene Price', '896314772871', 'irene.price@sakilacustomer.org'),
#  ('Jane Bennett', '918711376618', 'jane.bennett@sakilacustomer.org'),
#  ('Lori Wood', '875756771675', 'lori.wood@sakilacustomer.org'),
#  ('Rachel Barnes', '18581624103', 'rachel.barnes@sakilacustomer.org'),
#  ('Marilyn Ross', '701457319790', 'marilyn.ross@sakilacustomer.org'),
#  ('Andrea Henderson', '223664661973', 'andrea.henderson@sakilacustomer.org'),
#  ('Kathryn Coleman', '821972242086', 'kathryn.coleman@sakilacustomer.org'),
#  ('Louise Jenkins', '800716535041', 'louise.jenkins@sakilacustomer.org'),
#  ('Sara Perry', '48417642933', 'sara.perry@sakilacustomer.org'),
#  ('Anne Powell', '720998247660', 'anne.powell@sakilacustomer.org'),
#  ('Jacqueline Long', '135117278909', 'jacqueline.long@sakilacustomer.org'),
#  ('Wanda Patterson', '198123170793', 'wanda.patterson@sakilacustomer.org'),
#  ('Bonnie Hughes', '978987363654', 'bonnie.hughes@sakilacustomer.org'),
#  ('Julia Flores', '846225459260', 'julia.flores@sakilacustomer.org'),
#  ('Ruby Washington', '991562402283', 'ruby.washington@sakilacustomer.org'),
#  ('Lois Butler', '345679835036', 'lois.butler@sakilacustomer.org'),
#  ('Charlotte Hunter', '935448624185', 'charlotte.hunter@sakilacustomer.org'),
#  ('Monica Hicks', '252265130067', 'monica.hicks@sakilacustomer.org'),
#  ('Esther Crawford', '707169393853', 'esther.crawford@sakilacustomer.org'),
#  ('Pauline Henry', '321944036800', 'pauline.henry@sakilacustomer.org'),
#  ('Emma Boyd', '23712411567', 'emma.boyd@sakilacustomer.org'),
#  ('Juanita Mason', '90921003005', 'juanita.mason@sakilacustomer.org'),
#  ('Anita Morales', '146497509724', 'anita.morales@sakilacustomer.org'),
#  ('Rhonda Kennedy', '963369996279', 'rhonda.kennedy@sakilacustomer.org'),
#  ('Hazel Warren', '468060467018', 'hazel.warren@sakilacustomer.org'),
#  ('Amber Dixon', '33173584456', 'amber.dixon@sakilacustomer.org'),
#  ('Eva Ramos', '9099941466', 'eva.ramos@sakilacustomer.org'),
#  ('Debbie Reyes', '581852137991', 'debbie.reyes@sakilacustomer.org'),
#  ('April Burns', '581174211853', 'april.burns@sakilacustomer.org'),
#  ('Leslie Gordon', '923261616249', 'leslie.gordon@sakilacustomer.org'),
#  ('Clara Shaw', '563660187896', 'clara.shaw@sakilacustomer.org'),
#  ('Lucille Holmes', '918032330119', 'lucille.holmes@sakilacustomer.org'),
#  ('Jamie Rice', '206841104594', 'jamie.rice@sakilacustomer.org'),
#  ('Joanne Robertson', '597815221267', 'joanne.robertson@sakilacustomer.org'),
#  ('Eleanor Hunt', '354615066969', 'eleanor.hunt@sakilacustomer.org'),
#  ('Valerie Black', '885899703621', 'valerie.black@sakilacustomer.org'),
#  ('Danielle Daniels', '632316273199', 'danielle.daniels@sakilacustomer.org'),
#  ('Megan Palmer', '189446090264', 'megan.palmer@sakilacustomer.org'),
#  ('Alicia Mills', '761379480249', 'alicia.mills@sakilacustomer.org'),
#  ('Suzanne Nichols', '719202533520', 'suzanne.nichols@sakilacustomer.org'),
#  ('Michele Grant', '499408708580', 'michele.grant@sakilacustomer.org'),
#  ('Gail Knight', '904253967161', 'gail.knight@sakilacustomer.org'),
#  ('Bertha Ferguson', '889538496300', 'bertha.ferguson@sakilacustomer.org'),
#  ('Darlene Rose', '368899174225', 'darlene.rose@sakilacustomer.org'),
#  ('Veronica Stone', '170117068815', 'veronica.stone@sakilacustomer.org'),
#  ('Jill Hawkins', '931059836497', 'jill.hawkins@sakilacustomer.org'),
#  ('Erin Dunn', '149981248346', 'erin.dunn@sakilacustomer.org'),
#  ('Geraldine Perkins', '177167004331', 'geraldine.perkins@sakilacustomer.org'),
#  ('Lauren Hudson', '168476538960', 'lauren.hudson@sakilacustomer.org'),
#  ('Cathy Spencer', '819416131190', 'cathy.spencer@sakilacustomer.org'),
#  ('Joann Gardner', '697151428760', 'joann.gardner@sakilacustomer.org'),
#  ('Lorraine Stephens', '935508855935', 'lorraine.stephens@sakilacustomer.org'),
#  ('Lynn Payne', '843801144113', 'lynn.payne@sakilacustomer.org'),
#  ('Sally Pierce', '182363341674', 'sally.pierce@sakilacustomer.org'),
#  ('Viola Hanson', '569868543137', 'viola.hanson@sakilacustomer.org'),
#  ('Courtney Day', '890289150158', 'courtney.day@sakilacustomer.org'),
#  ('Marian Mendoza', '741070712873', 'marian.mendoza@sakilacustomer.org'),
#  ('Stella Moreno', '266798132374', 'stella.moreno@sakilacustomer.org'),
#  ('Caroline Bowman', '435785045362', 'caroline.bowman@sakilacustomer.org'),
#  ('Dora Medina', '56257502250', 'dora.medina@sakilacustomer.org'),
#  ('Jo Fowler', '716256596301', 'jo.fowler@sakilacustomer.org'),
#  ('Vickie Brewer', '567359279425', 'vickie.brewer@sakilacustomer.org'),
#  ('Mattie Hoffman', '246810237916', 'mattie.hoffman@sakilacustomer.org'),
#  ('Terry Carlson', '134673576619', 'terry.carlson@sakilacustomer.org'),
#  ('Maxine Silva', '840522972766', 'maxine.silva@sakilacustomer.org'),
#  ('Irma Pearson', '987442542471', 'irma.pearson@sakilacustomer.org'),
#  ('Mabel Holland', '884536620568', 'mabel.holland@sakilacustomer.org'),
#  ('Marsha Douglas', '245477603573', 'marsha.douglas@sakilacustomer.org'),
#  ('Myrtle Fleming', '46871694740', 'myrtle.fleming@sakilacustomer.org'),
#  ('Lena Jensen', '538241037443', 'lena.jensen@sakilacustomer.org'),
#  ('Christy Vargas', '276555730211', 'christy.vargas@sakilacustomer.org'),
#  ('Deanna Byrd', '265153400632', 'deanna.byrd@sakilacustomer.org'),
#  ('Patsy Davidson', '282874611748', 'patsy.davidson@sakilacustomer.org'),
#  ('Hilda Hopkins', '322888976727', 'hilda.hopkins@sakilacustomer.org'),
#  ('Gwendolyn May', '303967439816', 'gwendolyn.may@sakilacustomer.org'),
#  ('Jennie Terry', '475553436330', 'jennie.terry@sakilacustomer.org'),
#  ('Nora Herrera', '621625204422', 'nora.herrera@sakilacustomer.org'),
#  ('Margie Wade', '192459639410', 'margie.wade@sakilacustomer.org'),
#  ('Nina Soto', '357445645426', 'nina.soto@sakilacustomer.org'),
#  ('Cassandra Walters', '685010736240', 'cassandra.walters@sakilacustomer.org'),
#  ('Leah Curtis', '701767622697', 'leah.curtis@sakilacustomer.org'),
#  ('Penny Neal', '271149517630', 'penny.neal@sakilacustomer.org'),
#  ('Kay Caldwell', '170739645687', 'kay.caldwell@sakilacustomer.org'),
#  ('Priscilla Lowe', '45387294817', 'priscilla.lowe@sakilacustomer.org'),
#  ('Naomi Jennings', '959949395183', 'naomi.jennings@sakilacustomer.org'),
#  ('Carole Barnett', '874337098891', 'carole.barnett@sakilacustomer.org'),
#  ('Brandy Graves', '75975221996', 'brandy.graves@sakilacustomer.org'),
#  ('Olga Jimenez', '363982224739', 'olga.jimenez@sakilacustomer.org'),
#  ('Billie Horton', '880756161823', 'billie.horton@sakilacustomer.org'),
#  ('Dianne Shelton', '117592274996', 'dianne.shelton@sakilacustomer.org'),
#  ('Tracey Barrett', '85059738746', 'tracey.barrett@sakilacustomer.org'),
#  ('Leona Obrien', '583021225407', 'leona.obrien@sakilacustomer.org'),
#  ('Jenny Castro', '62781725285', 'jenny.castro@sakilacustomer.org'),
#  ('Felicia Sutton', '790651020929', 'felicia.sutton@sakilacustomer.org'),
#  ('Sonia Gregory', '195003555232', 'sonia.gregory@sakilacustomer.org'),
#  ('Miriam Mckinney', '341242939532', 'miriam.mckinney@sakilacustomer.org'),
#  ('Velma Lucas', '558236142492', 'velma.lucas@sakilacustomer.org'),
#  ('Becky Miles', '648482415405', 'becky.miles@sakilacustomer.org'),
#  ('Bobbie Craig', '957128697225', 'bobbie.craig@sakilacustomer.org'),
#  ('Violet Rodriquez', '172262454487', 'violet.rodriquez@sakilacustomer.org'),
#  ('Kristina Chambers', '892523334', 'kristina.chambers@sakilacustomer.org'),
#  ('Toni Holt', '976798660411', 'toni.holt@sakilacustomer.org'),
#  ('Misty Lambert', '350970907017', 'misty.lambert@sakilacustomer.org'),
#  ('Mae Fletcher', '96604821070', 'mae.fletcher@sakilacustomer.org'),
#  ('Shelly Watts', '967274728547', 'shelly.watts@sakilacustomer.org'),
#  ('Daisy Bates', '816436065431', 'daisy.bates@sakilacustomer.org'),
#  ('Ramona Hale', '429925609431', 'ramona.hale@sakilacustomer.org'),
#  ('Sherri Rhodes', '510737228015', 'sherri.rhodes@sakilacustomer.org'),
#  ('Erika Pena', '161643343536', 'erika.pena@sakilacustomer.org'),
#  ('James Gannon', '710603868323', 'james.gannon@sakilacustomer.org'),
#  ('John Farnsworth', '51917807050', 'john.farnsworth@sakilacustomer.org'),
#  ('Robert Baughman', '96110042435', 'robert.baughman@sakilacustomer.org'),
#  ('Michael Silverman', '108053751300', 'michael.silverman@sakilacustomer.org'),
#  ('William Satterfield', '407218522294', 'william.satterfield@sakilacustomer.org'),
#  ('David Royal', '504434452842', 'david.royal@sakilacustomer.org'),
#  ('Richard Mccrary', '262088367001', 'richard.mccrary@sakilacustomer.org'),
#  ('Charles Kowalski', '181179321332', 'charles.kowalski@sakilacustomer.org'),
#  ('Joseph Joy', '573441801529', 'joseph.joy@sakilacustomer.org'),
#  ('Thomas Grigsby', '983259819766', 'thomas.grigsby@sakilacustomer.org'),
#  ('Christopher Greco', '806016930576', 'christopher.greco@sakilacustomer.org'),
#  ('Daniel Cabral', '103602195112', 'daniel.cabral@sakilacustomer.org'),
#  ('Paul Trout', '688485191923', 'paul.trout@sakilacustomer.org'),
#  ('Mark Rinehart', '824396883951', 'mark.rinehart@sakilacustomer.org'),
#  ('Donald Mahon', '613124286867', 'donald.mahon@sakilacustomer.org'),
#  ('George Linton', '704948322302', 'george.linton@sakilacustomer.org'),
#  ('Kenneth Gooden', '508800331065', 'kenneth.gooden@sakilacustomer.org'),
#  ('Steven Curley', '139378397418', 'steven.curley@sakilacustomer.org'),
#  ('Edward Baugh', '46568045367', 'edward.baugh@sakilacustomer.org'),
#  ('Brian Wyman', '556100547674', 'brian.wyman@sakilacustomer.org'),
#  ('Ronald Weiner', '674805712553', 'ronald.weiner@sakilacustomer.org'),
#  ('Anthony Schwab', '478229987054', 'anthony.schwab@sakilacustomer.org'),
#  ('Jimmy Schrader', '604177838256', 'jimmy.schrader@sakilacustomer.org'),
#  ('Antonio Meek', '841876514789', 'antonio.meek@sakilacustomer.org'),
#  ('Danny Isom', '280578750435', 'danny.isom@sakilacustomer.org'),
#  ('Bryan Hardison', '775235029633', 'bryan.hardison@sakilacustomer.org'),
#  ('Tony Carranza', '794553031307', 'tony.carranza@sakilacustomer.org'),
#  ('Luis Yanez', '516647474029', 'luis.yanez@sakilacustomer.org'),
#  ('Mike Way', '206169448769', 'mike.way@sakilacustomer.org'),
#  ('Stanley Scroggins', '1483365694', 'stanley.scroggins@sakilacustomer.org'),
#  ('Leonard Schofield', '779461480495', 'leonard.schofield@sakilacustomer.org'),
#  ('Nathan Runyon', '302526949177', 'nathan.runyon@sakilacustomer.org'),
#  ('Dale Ratcliff', '328494873422', 'dale.ratcliff@sakilacustomer.org'),
#  ('Manuel Murrell', '359478883004', 'manuel.murrell@sakilacustomer.org'),
#  ('Rodney Moeller', '653436985797', 'rodney.moeller@sakilacustomer.org'),
#  ('Curtis Irby', '615964523510', 'curtis.irby@sakilacustomer.org'),
#  ('Norman Currier', '598912394463', 'norman.currier@sakilacustomer.org'),
#  ('Allen Butterfield', '129953030512', 'allen.butterfield@sakilacustomer.org'),
#  ('Marvin Yee', '480039662421', 'marvin.yee@sakilacustomer.org'),
#  ('Vincent Ralston', '680851640676', 'vincent.ralston@sakilacustomer.org'),
#  ('Glenn Pullen', '855290087237', 'glenn.pullen@sakilacustomer.org'),
#  ('Jeffery Pinson', '15273765306', 'jeffery.pinson@sakilacustomer.org'),
#  ('Travis Estep', '214976066017', 'travis.estep@sakilacustomer.org'),
#  ('Jeff East', '491271355190', 'jeff.east@sakilacustomer.org'),
#  ('Chad Carbone', '987306329957', 'chad.carbone@sakilacustomer.org'),
#  ('Jacob Lance', '546793516940', 'jacob.lance@sakilacustomer.org'),
#  ('Lee Hawks', '270456873752', 'lee.hawks@sakilacustomer.org'),
#  ('Melvin Ellington', '368284120423', 'melvin.ellington@sakilacustomer.org'),
#  ('Alfred Casillas', '129673677866', 'alfred.casillas@sakilacustomer.org'),
#  ('Kyle Spurlock', '736517327853', 'kyle.spurlock@sakilacustomer.org'),
#  ('Francis Sikes', '548003849552', 'francis.sikes@sakilacustomer.org'),
#  ('Bradley Motley', '157133457169', 'bradley.motley@sakilacustomer.org'),
#  ('Jesus Mccartney', '419009857119', 'jesus.mccartney@sakilacustomer.org'),
#  ('Herbert Kruger', '307133768620', 'herbert.kruger@sakilacustomer.org'),
#  ('Frederick Isbell', '572068624538', 'frederick.isbell@sakilacustomer.org'),
#  ('Ray Houle', '497288595103', 'ray.houle@sakilacustomer.org'),
#  ('Joel Francisco', '82619513349', 'joel.francisco@sakilacustomer.org'),
#  ('Edwin Burk', '617567598243', 'edwin.burk@sakilacustomer.org'),
#  ('Don Bone', '342709348083', 'don.bone@sakilacustomer.org'),
#  ('Eddie Tomlin', '959834530529', 'eddie.tomlin@sakilacustomer.org'),
#  ('Guy Brownlee', '978430786151', 'guy.brownlee@sakilacustomer.org'),
#  ('Clayton Barbee', '380077794770', 'clayton.barbee@sakilacustomer.org'),
#  ('Hugh Waldrop', '955349440539', 'hugh.waldrop@sakilacustomer.org'),
#  ('Max Pitt', '698182547686', 'max.pitt@sakilacustomer.org'),
#  ('Dwayne Olvera', '62127829280', 'dwayne.olvera@sakilacustomer.org'),
#  ('Dwight Lombardi', '368738360376', 'dwight.lombardi@sakilacustomer.org'),
#  ('Armando Gruber', '590764256785', 'armando.gruber@sakilacustomer.org'),
#  ('Felix Gaffney', '107092893983', 'felix.gaffney@sakilacustomer.org'),
#  ('Jimmie Eggleston', '970638808606', 'jimmie.eggleston@sakilacustomer.org'),
#  ('Everett Banda', '855066328617', 'everett.banda@sakilacustomer.org'),
#  ('Jordan Archuleta', '817740355461', 'jordan.archuleta@sakilacustomer.org'),
#  ('Ian Still', '239357986667', 'ian.still@sakilacustomer.org'),
#  ('Wallace Slone', '946114054231', 'wallace.slone@sakilacustomer.org'),
#  ('Ken Prewitt', '997453607116', 'ken.prewitt@sakilacustomer.org'),
#  ('Bob Pfeiffer', '203202500108', 'bob.pfeiffer@sakilacustomer.org'),
#  ('Jaime Nettles', '863080561151', 'jaime.nettles@sakilacustomer.org'),
#  ('Casey Mena', '525518075499', 'casey.mena@sakilacustomer.org'),
#  ('Alfredo Mcadams', '324346485054', 'alfredo.mcadams@sakilacustomer.org'),
#  ('Alberto Henning', '618156722572', 'alberto.henning@sakilacustomer.org'),
#  ('Dave Gardiner', '128499386727', 'dave.gardiner@sakilacustomer.org'),
#  ('Ivan Cromwell', '203804046132', 'ivan.cromwell@sakilacustomer.org'),
#  ('Johnnie Chisholm', '770864062795', 'johnnie.chisholm@sakilacustomer.org'),
#  ('Sidney Burleson', '867287719310', 'sidney.burleson@sakilacustomer.org'),
#  ('Byron Box', '844018348565', 'byron.box@sakilacustomer.org'),
#  ('Julian Vest', '315528269898', 'julian.vest@sakilacustomer.org'),
#  ('Isaac Oglesby', '14465669789', 'isaac.oglesby@sakilacustomer.org'),
#  ('Morris Mccarter', '278669994384', 'morris.mccarter@sakilacustomer.org'),
#  ('Clifton Malcolm', '29341849811', 'clifton.malcolm@sakilacustomer.org'),
#  ('Willard Lumpkin', '377633994405', 'willard.lumpkin@sakilacustomer.org'),
#  ('Daryl Larue', '954786054144', 'daryl.larue@sakilacustomer.org'),
#  ('Ross Grey', '165164761435', 'ross.grey@sakilacustomer.org'),
#  ('Virgil Wofford', '294449058179', 'virgil.wofford@sakilacustomer.org'),
#  ('Andy Vanhorn', '995527378381', 'andy.vanhorn@sakilacustomer.org'),
#  ('Marshall Thorn', '285710089439', 'marshall.thorn@sakilacustomer.org'),
#  ('Salvador Teel', '170115379190', 'salvador.teel@sakilacustomer.org'),
#  ('Perry Swafford', '914466027044', 'perry.swafford@sakilacustomer.org'),
#  ('Kirk Stclair', '182178609211', 'kirk.stclair@sakilacustomer.org'),
#  ('Sergio Stanfield', '387448063440', 'sergio.stanfield@sakilacustomer.org'),
#  ('Marion Ocampo', '338758048786', 'marion.ocampo@sakilacustomer.org'),
#  ('Tracy Herrmann', '154124128457', 'tracy.herrmann@sakilacustomer.org'),
#  ('Seth Hannon', '864392582257', 'seth.hannon@sakilacustomer.org'),
#  ('Kent Arsenault', '410877354933', 'kent.arsenault@sakilacustomer.org'),
#  ('Terrance Roush', '437829801725', 'terrance.roush@sakilacustomer.org'),
#  ('Rene Mcalister', '137809746111', 'rene.mcalister@sakilacustomer.org'),
#  ('Eduardo Hiatt', '640843562301', 'eduardo.hiatt@sakilacustomer.org'),
#  ('Terrence Gunderson', '935952366111', 'terrence.gunderson@sakilacustomer.org'),
#  ('Enrique Forsythe', '199514580428', 'enrique.forsythe@sakilacustomer.org'),
#  ('Freddie Duggan', '644021380889', 'freddie.duggan@sakilacustomer.org'),
#  ('Wade Delvalle', '145308717464', 'wade.delvalle@sakilacustomer.org'),
#  ('Austin Cintron', '288241215394', 'austin.cintron@sakilacustomer.org')]

# %% [markdown]
# ## 2. Who are the top 20 active customers with the highest total payment contributions?

# %%
# %%sql
# SELECT
#     c.customer_id,
#     CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#     total_payment
# FROM
#     (SELECT
#         p.customer_id,
#         SUM(p.amount) AS total_payment
#     FROM payment AS p
#     INNER JOIN customer AS c ON p.customer_id = c.customer_id
#     WHERE active = 1
#     GROUP BY p.customer_id
#     ) AS subquery
# INNER JOIN customer AS c ON subquery.customer_id = c.customer_id
# ORDER BY total_payment DESC, c.customer_id
# LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 20 rows affected.
# [(148, 'Eleanor Hunt', Decimal('211.55')),
#  (526, 'Karl Seal', Decimal('208.58')),
#  (178, 'Marion Snyder', Decimal('194.61')),
#  (137, 'Rhonda Kennedy', Decimal('191.62')),
#  (144, 'Clara Shaw', Decimal('189.60')),
#  (459, 'Tommy Collazo', Decimal('183.63')),
#  (181, 'Ana Bradley', Decimal('167.67')),
#  (410, 'Curtis Irby', Decimal('167.62')),
#  (236, 'Marcia Dean', Decimal('166.61')),
#  (403, 'Mike Way', Decimal('162.67')),
#  (522, 'Arnold Havens', Decimal('161.68')),
#  (469, 'Wesley Bull', Decimal('158.65')),
#  (470, 'Gordon Allard', Decimal('157.69')),
#  (373, 'Louis Leone', Decimal('156.66')),
#  (259, 'Lena Jensen', Decimal('154.70')),
#  (468, 'Tim Cary', Decimal('154.66')),
#  (462, 'Warren Sherrod', Decimal('152.69')),
#  (372, 'Steve Mackenzie', Decimal('152.68')),
#  (187, 'Brittany Riley', Decimal('151.73')),
#  (550, 'Guy Brownlee', Decimal('151.69'))]

# %% [markdown]
# The analysis indicates that the top 20 active customers have total payment amounts ranging from $150 to $210. In our next session, we will further investigate their geographical distribution to gain insights into their locations.

# %% [markdown]
# ## 3. Where are these top 20 active contributing customers based in?

# %%
# %%sql
# SELECT
#     c.customer_id,
#     CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#     total_payment,
#     city.city,
#     country.country
# FROM
#     (SELECT
#         p.customer_id,
#         SUM(p.amount) AS total_payment
#     FROM payment AS p
#     INNER JOIN customer AS c ON p.customer_id = c.customer_id
#     WHERE active = 1
#     GROUP BY p.customer_id
#     ) AS subquery
# INNER JOIN customer AS c ON subquery.customer_id = c.customer_id
# INNER JOIN address AS a ON c.address_id = a.address_id
# INNER JOIN city ON a.city_id = city.city_id
# INNER JOIN country ON city.country_id = country.country_id
# ORDER BY total_payment DESC, c.customer_id
# LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 20 rows affected.
# [(148, 'Eleanor Hunt', Decimal('211.55'), 'Saint-Denis', 'Runion'),
#  (526, 'Karl Seal', Decimal('208.58'), 'Cape Coral', 'United States'),
#  (178, 'Marion Snyder', Decimal('194.61'), 'Santa Brbara dOeste', 'Brazil'),
#  (137, 'Rhonda Kennedy', Decimal('191.62'), 'Apeldoorn', 'Netherlands'),
#  (144, 'Clara Shaw', Decimal('189.60'), 'Molodetno', 'Belarus'),
#  (459, 'Tommy Collazo', Decimal('183.63'), 'Qomsheh', 'Iran'),
#  (181, 'Ana Bradley', Decimal('167.67'), 'Memphis', 'United States'),
#  (410, 'Curtis Irby', Decimal('167.62'), 'Richmond Hill', 'Canada'),
#  (236, 'Marcia Dean', Decimal('166.61'), 'Tanza', 'Philippines'),
#  (403, 'Mike Way', Decimal('162.67'), 'Valparai', 'India'),
#  (522, 'Arnold Havens', Decimal('161.68'), 'Santa Rosa', 'Philippines'),
#  (469, 'Wesley Bull', Decimal('158.65'), 'Ourense (Orense)', 'Spain'),
#  (470, 'Gordon Allard', Decimal('157.69'), 'Hodeida', 'Yemen'),
#  (373, 'Louis Leone', Decimal('156.66'), 'Tanauan', 'Philippines'),
#  (259, 'Lena Jensen', Decimal('154.70'), 'Halisahar', 'India'),
#  (468, 'Tim Cary', Decimal('154.66'), 'Bijapur', 'India'),
#  (462, 'Warren Sherrod', Decimal('152.69'), 'Usolje-Sibirskoje', 'Russian Federation'),
#  (372, 'Steve Mackenzie', Decimal('152.68'), 'Probolinggo', 'Indonesia'),
#  (187, 'Brittany Riley', Decimal('151.73'), 'Sumy', 'Ukraine'),
#  (550, 'Guy Brownlee', Decimal('151.69'), 'Zhoushan', 'China')]

# %% [markdown]
# The top 20 active contributing customers are located in different ontinents and cities representing their diverse geographical distribution. Interestingly, there is no specific location or country dominating the list of top 20 active customers, indicating a global reach and a diverse customer base contributing to the business's revenue.

# %% [markdown]
# ## 4. Who are the top 20 active frequent customers?

# %%
# %%sql
# WITH customer_engagement AS (
#     SELECT
#         c.customer_id,
#         CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#         COUNT(r.rental_id) AS total_rental_count
#     FROM customer AS c
#     LEFT JOIN rental AS r ON c.customer_id = r.customer_id
#     WHERE active = 1
#     GROUP BY c.customer_id, full_name
# ),
# average_engagement AS (
#     SELECT
#         AVG(total_rental_count) AS avg_total_rental_count
#     FROM customer_engagement
# ),
# top_customers AS (
#     SELECT
#         c.customer_id,
#         CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#         total_payment
#     FROM
#         (SELECT
#             p.customer_id,
#             SUM(p.amount) AS total_payment
#         FROM payment AS p
#         INNER JOIN customer AS c ON p.customer_id = c.customer_id
#         WHERE active = 1
#         GROUP BY p.customer_id
#         ) AS subquery
#     INNER JOIN customer AS c ON subquery.customer_id = c.customer_id
#     ORDER BY total_payment DESC, c.customer_id
#     LIMIT 20
# )
# SELECT
#     tc.customer_id,
#     tc.full_name,
#     tc.total_payment,
#     ce.total_rental_count
# FROM top_customers AS tc
# INNER JOIN customer_engagement AS ce ON tc.customer_id = ce.customer_id
# CROSS JOIN average_engagement AS ae
# WHERE ce.total_rental_count >= ae.avg_total_rental_count
# ORDER BY ce.total_rental_count DESC, tc.customer_id;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 20 rows affected.
# [(148, 'Eleanor Hunt', Decimal('211.55'), 46),
#  (526, 'Karl Seal', Decimal('208.58'), 45),
#  (144, 'Clara Shaw', Decimal('189.60'), 42),
#  (236, 'Marcia Dean', Decimal('166.61'), 42),
#  (469, 'Wesley Bull', Decimal('158.65'), 40),
#  (137, 'Rhonda Kennedy', Decimal('191.62'), 39),
#  (178, 'Marion Snyder', Decimal('194.61'), 39),
#  (468, 'Tim Cary', Decimal('154.66'), 39),
#  (410, 'Curtis Irby', Decimal('167.62'), 38),
#  (459, 'Tommy Collazo', Decimal('183.63'), 38),
#  (373, 'Louis Leone', Decimal('156.66'), 35),
#  (403, 'Mike Way', Decimal('162.67'), 35),
#  (181, 'Ana Bradley', Decimal('167.67'), 34),
#  (372, 'Steve Mackenzie', Decimal('152.68'), 34),
#  (462, 'Warren Sherrod', Decimal('152.69'), 33),
#  (522, 'Arnold Havens', Decimal('161.68'), 33),
#  (259, 'Lena Jensen', Decimal('154.70'), 32),
#  (470, 'Gordon Allard', Decimal('157.69'), 32),
#  (550, 'Guy Brownlee', Decimal('151.69'), 32),
#  (187, 'Brittany Riley', Decimal('151.73'), 28)]

# %% [markdown]
# Based on the results, it is evident that the top 20 active frequent customers and the top 20 active contributing customers share a strikingly similar composition, with only one user differing between the two groups. This observation provides strong evidence of a positive correlation between rental frequency and total rental payments. In other words, customers who rent movies more frequently also tend to make higher total rental payments, reinforcing the idea that increased rental activity leads to higher spending. In the next session, the analysis of customers in terms of rental duration will be examined.

# %% [markdown]
# ## 5. Who are the top 20 active long term renters?

# %%
# %%sql
# WITH customer_engagement AS (
#     SELECT
#         c.customer_id,
#         CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#         SUM(EXTRACT(DAY FROM r.return_date - r.rental_date)) AS total_rental_duration
#     FROM customer AS c
#     LEFT JOIN rental AS r ON c.customer_id = r.customer_id
#     WHERE active = 1
#     GROUP BY c.customer_id, full_name
# ),
# average_engagement AS (
#     SELECT
#         AVG(total_rental_duration) AS avg_rental_duration
#     FROM customer_engagement
# ),
# top_customers AS (
#     SELECT
#         c.customer_id,
#         CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#         total_payment
#     FROM
#         (SELECT
#             p.customer_id,
#             SUM(p.amount) AS total_payment
#         FROM payment AS p
#         INNER JOIN customer AS c ON p.customer_id = c.customer_id
#         WHERE active = 1
#         GROUP BY p.customer_id
#         ) AS subquery
#     INNER JOIN customer AS c ON subquery.customer_id = c.customer_id
#     ORDER BY total_payment DESC, c.customer_id
#     LIMIT 20
# )
# SELECT
#     tc.customer_id,
#     tc.full_name,
#     tc.total_payment,
#     ce.total_rental_duration
# FROM top_customers AS tc
# INNER JOIN customer_engagement AS ce ON tc.customer_id = ce.customer_id
# CROSS JOIN average_engagement AS ae
# WHERE ce.total_rental_duration >= ae.avg_rental_duration
# ORDER BY ce.total_rental_duration DESC, tc.customer_id;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 20 rows affected.
# [(526, 'Karl Seal', Decimal('208.58'), Decimal('241')),
#  (148, 'Eleanor Hunt', Decimal('211.55'), Decimal('218')),
#  (144, 'Clara Shaw', Decimal('189.60'), Decimal('211')),
#  (137, 'Rhonda Kennedy', Decimal('191.62'), Decimal('209')),
#  (469, 'Wesley Bull', Decimal('158.65'), Decimal('203')),
#  (468, 'Tim Cary', Decimal('154.66'), Decimal('200')),
#  (178, 'Marion Snyder', Decimal('194.61'), Decimal('195')),
#  (236, 'Marcia Dean', Decimal('166.61'), Decimal('187')),
#  (181, 'Ana Bradley', Decimal('167.67'), Decimal('184')),
#  (410, 'Curtis Irby', Decimal('167.62'), Decimal('181')),
#  (522, 'Arnold Havens', Decimal('161.68'), Decimal('181')),
#  (373, 'Louis Leone', Decimal('156.66'), Decimal('177')),
#  (259, 'Lena Jensen', Decimal('154.70'), Decimal('174')),
#  (459, 'Tommy Collazo', Decimal('183.63'), Decimal('173')),
#  (187, 'Brittany Riley', Decimal('151.73'), Decimal('167')),
#  (462, 'Warren Sherrod', Decimal('152.69'), Decimal('159')),
#  (372, 'Steve Mackenzie', Decimal('152.68'), Decimal('151')),
#  (470, 'Gordon Allard', Decimal('157.69'), Decimal('149')),
#  (403, 'Mike Way', Decimal('162.67'), Decimal('140')),
#  (550, 'Guy Brownlee', Decimal('151.69'), Decimal('139'))]

# %% [markdown]
# Based on the findings, it is noteworthy that the top 20 active long-term customers and the top 20 active frequent customers are identical, albeit in different orders. This observation highlights a positive correlation between rental duration and total rental payments. The fact that the same customers appear in both segments indicates that those who rent movies more frequently also tend to keep them for longer periods, leading to higher total rental payments. As a result of this discovery, we plan to classify customers into different segments based on their rental frequency and duration.

# %% [markdown]
# ## 6. What is the rental segment of top 20 active contributing customers?

# %%
# %%sql
# WITH customer_engagement AS (
#     SELECT
#         c.customer_id,
#         CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#         COUNT(r.rental_id) AS total_rental_count,
#         SUM(EXTRACT(DAY FROM r.return_date - r.rental_date)) AS total_rental_duration
#     FROM customer AS c
#     LEFT JOIN rental AS r ON c.customer_id = r.customer_id
#     WHERE active = 1
#     GROUP BY c.customer_id, full_name
# ),
# average_engagement AS (
#     SELECT
#         AVG(total_rental_count) AS avg_total_rental_count,
#         AVG(total_rental_duration) AS avg_rental_duration
#     FROM customer_engagement
# ),
# top_customers AS (
#     SELECT
#         c.customer_id,
#         CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#         total_payment
#     FROM
#         (SELECT
#             p.customer_id,
#             SUM(p.amount) AS total_payment
#         FROM payment AS p
#         INNER JOIN customer AS c ON p.customer_id = c.customer_id
#         WHERE active = 1
#         GROUP BY p.customer_id
#         ) AS subquery
#     INNER JOIN customer AS c ON subquery.customer_id = c.customer_id
#     ORDER BY total_payment DESC, c.customer_id
#     LIMIT 20
# )
# SELECT
#     tc.customer_id,
#     tc.full_name,
#     tc.total_payment,
#     ce.total_rental_count,
#     ce.total_rental_duration,
#     CASE
#         WHEN ce.total_rental_count >= ae.avg_total_rental_count AND ce.total_rental_duration >= ae.avg_rental_duration THEN 'Frequent and Long-Term Renter'
#         WHEN ce.total_rental_count >= ae.avg_total_rental_count AND ce.total_rental_duration < ae.avg_rental_duration THEN 'Frequent but Short-Term Renter'
#         WHEN ce.total_rental_count < ae.avg_total_rental_count AND ce.total_rental_duration >= ae.avg_rental_duration THEN 'Infrequent but Long-Term Renter'
#         ELSE 'Infrequent and Short-Term Renter'
#     END AS rental_segment
# FROM top_customers AS tc
# INNER JOIN customer_engagement AS ce ON tc.customer_id = ce.customer_id
# CROSS JOIN average_engagement AS ae
# ORDER BY tc.total_payment DESC, tc.customer_id;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 20 rows affected.
# [(148, 'Eleanor Hunt', Decimal('211.55'), 46, Decimal('218'), 'Frequent and Long-Term Renter'),
#  (526, 'Karl Seal', Decimal('208.58'), 45, Decimal('241'), 'Frequent and Long-Term Renter'),
#  (178, 'Marion Snyder', Decimal('194.61'), 39, Decimal('195'), 'Frequent and Long-Term Renter'),
#  (137, 'Rhonda Kennedy', Decimal('191.62'), 39, Decimal('209'), 'Frequent and Long-Term Renter'),
#  (144, 'Clara Shaw', Decimal('189.60'), 42, Decimal('211'), 'Frequent and Long-Term Renter'),
#  (459, 'Tommy Collazo', Decimal('183.63'), 38, Decimal('173'), 'Frequent and Long-Term Renter'),
#  (181, 'Ana Bradley', Decimal('167.67'), 34, Decimal('184'), 'Frequent and Long-Term Renter'),
#  (410, 'Curtis Irby', Decimal('167.62'), 38, Decimal('181'), 'Frequent and Long-Term Renter'),
#  (236, 'Marcia Dean', Decimal('166.61'), 42, Decimal('187'), 'Frequent and Long-Term Renter'),
#  (403, 'Mike Way', Decimal('162.67'), 35, Decimal('140'), 'Frequent and Long-Term Renter'),
#  (522, 'Arnold Havens', Decimal('161.68'), 33, Decimal('181'), 'Frequent and Long-Term Renter'),
#  (469, 'Wesley Bull', Decimal('158.65'), 40, Decimal('203'), 'Frequent and Long-Term Renter'),
#  (470, 'Gordon Allard', Decimal('157.69'), 32, Decimal('149'), 'Frequent and Long-Term Renter'),
#  (373, 'Louis Leone', Decimal('156.66'), 35, Decimal('177'), 'Frequent and Long-Term Renter'),
#  (259, 'Lena Jensen', Decimal('154.70'), 32, Decimal('174'), 'Frequent and Long-Term Renter'),
#  (468, 'Tim Cary', Decimal('154.66'), 39, Decimal('200'), 'Frequent and Long-Term Renter'),
#  (462, 'Warren Sherrod', Decimal('152.69'), 33, Decimal('159'), 'Frequent and Long-Term Renter'),
#  (372, 'Steve Mackenzie', Decimal('152.68'), 34, Decimal('151'), 'Frequent and Long-Term Renter'),
#  (187, 'Brittany Riley', Decimal('151.73'), 28, Decimal('167'), 'Frequent and Long-Term Renter'),
#  (550, 'Guy Brownlee', Decimal('151.69'), 32, Decimal('139'), 'Frequent and Long-Term Renter')]

# %% [markdown]
# The data presented in the table clearly demonstrates that customers who rent movies frequently and keep them for longer periods are more likely to contribute significantly to the sales. This highlights the importance of customer loyalty and engagement in driving revenue growth for the rental service. Therefore, it is essential for the service to focus on retaining and catering to the preferences of these highly engaged customers to maximize their revenue potential. In the next session, we will be computing the total number of current frequent and long-term renters to understand the business performance.

# %% [markdown]
# ## 7. How many customer are frequent and long-term renters?

# %%
# %%sql
# WITH customer_engagement AS (
#     SELECT
#         c.customer_id,
#         COUNT(r.rental_id) AS total_rental_count,
#         SUM(EXTRACT(DAY FROM r.return_date - r.rental_date)) AS total_rental_duration
#     FROM customer AS c
#     LEFT JOIN rental AS r ON c.customer_id = r.customer_id
#     WHERE active = 1
#     GROUP BY c.customer_id
# ),
# average_engagement AS (
#     SELECT
#         AVG(total_rental_count) AS avg_total_rental_count,
#         AVG(total_rental_duration) AS avg_rental_duration
#     FROM customer_engagement
# )
# SELECT COUNT(ce.customer_id) AS frequent_long_term_renters_count
# FROM customer_engagement AS ce
# CROSS JOIN average_engagement AS ae
# WHERE ce.total_rental_count >= ae.avg_total_rental_count AND ce.total_rental_duration >= ae.avg_rental_duration;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(241,)]

# %% [markdown]
# Currently, there are 241 active unique customers who fall under the category of frequent and long-term renters, making up approximately 40.23% of the total customer base. This ratio is quite promising, suggesting a significant proportion of engaged customers. Moving forward, the strategy could concentrate on nurturing the loyalty of these active customers while also aiming to convert more customers into frequent and long-term renters. To gain further insights into the geographic distribution of these valuable customers, the following analysis is provided below:

# %% [markdown]
# ## 8. How is the customer base distributed across different countries? What are the total sales figures in each country?

# %%
# %%sql
# SELECT COUNT(DISTINCT(country))
# FROM country;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(109,)]

# %% [markdown]
# There are 109 unique countries in this dataset.

# %%
# %%sql
# WITH customer_engagement AS (
#     SELECT
#         c.customer_id,
#         CONCAT(c.first_name, ' ', c.last_name) AS full_name,
#         COUNT(r.rental_id) AS total_rental_count,
#         SUM(EXTRACT(DAY FROM r.return_date - r.rental_date)) AS total_rental_duration
#     FROM customer AS c
#     LEFT JOIN rental AS r ON c.customer_id = r.customer_id
#     GROUP BY c.customer_id, full_name
# ),
# average_engagement AS (
#     SELECT
#         AVG(total_rental_count) AS avg_total_rental_count,
#         AVG(total_rental_duration) AS avg_rental_duration
#     FROM customer_engagement
# ),
# customer_segment AS (
#     SELECT
#         ce.customer_id,
#         ce.full_name,
#         ce.total_rental_count,
#         ce.total_rental_duration,
#         CASE
#             WHEN ce.total_rental_count >= ae.avg_total_rental_count AND ce.total_rental_duration >= ae.avg_rental_duration THEN 'Frequent and Long-Term Renter'
#             ELSE 'Other'
#         END AS rental_segment
#     FROM customer_engagement AS ce
#     CROSS JOIN average_engagement AS ae
# )
# SELECT
#     country.country,
#     COUNT(DISTINCT(c.customer_id)) AS unique_customer_count,
#     COUNT(DISTINCT CASE WHEN cs.rental_segment = 'Frequent and Long-Term Renter' THEN cs.customer_id END) AS frequent_long_term_renters_count,
#     COUNT(r.rental_id) AS rental_count,
#     SUM(p.amount) AS total_sales
# FROM customer AS c
# INNER JOIN payment AS p ON c.customer_id = p.customer_id
# INNER JOIN rental AS r ON r.rental_id = p.rental_id
# INNER JOIN address AS a ON c.address_id = a.address_id
# INNER JOIN city ON a.city_id = city.city_id
# INNER JOIN country ON city.country_id = country.country_id
# LEFT JOIN customer_segment AS cs ON c.customer_id = cs.customer_id
# GROUP BY country.country_id
# ORDER BY total_sales DESC
# LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 20 rows affected.
# [('India', 60, 24, 1422, Decimal('6034.78')),
#  ('China', 53, 24, 1297, Decimal('5251.03')),
#  ('United States', 36, 17, 869, Decimal('3685.31')),
#  ('Japan', 31, 12, 749, Decimal('3122.51')),
#  ('Mexico', 30, 9, 718, Decimal('2984.82')),
#  ('Brazil', 28, 14, 681, Decimal('2919.19')),
#  ('Russian Federation', 28, 7, 638, Decimal('2765.62')),
#  ('Philippines', 20, 11, 530, Decimal('2219.70')),
#  ('Turkey', 15, 5, 351, Decimal('1498.49')),
#  ('Indonesia', 14, 5, 331, Decimal('1352.69')),
#  ('Nigeria', 13, 6, 308, Decimal('1314.92')),
#  ('Argentina', 13, 6, 320, Decimal('1298.80')),
#  ('Taiwan', 10, 7, 290, Decimal('1155.10')),
#  ('South Africa', 11, 4, 254, Decimal('1069.46')),
#  ('Iran', 8, 3, 204, Decimal('877.96')),
#  ('United Kingdom', 9, 0, 204, Decimal('850.96')),
#  ('Poland', 8, 3, 184, Decimal('786.16')),
#  ('Italy', 7, 4, 174, Decimal('753.26')),
#  ('Germany', 7, 2, 176, Decimal('741.24')),
#  ('Vietnam', 6, 4, 155, Decimal('676.45'))]

# %% [markdown]
# The comprehensive analysis reveals a notable correlation between the top 8 countries in terms of total sales and the presence of frequent and long-term customers. These countries include India, China, United States, Japan, Mexico, Brazil, Russian Federation, and Philippines. Remarkably, these countries collectively harbor 118 frequent and long-term customers, constituting 48.96% of the total customer count. These countries present an ideal focus for implementing a customer loyalty program to further strengthen customer engagement and drive growth in the rental service.

# %% [markdown]
# ## 9. What is the percentage of total sales contributed by the top 10 countries?

# %%
# %%sql
# WITH country_sales AS (
#     SELECT country.country,
#            SUM(p.amount) AS total_sales
#     FROM customer AS c
#     INNER JOIN payment AS p ON c.customer_id = p.customer_id
#     INNER JOIN rental AS r ON r.rental_id = p.rental_id
#     INNER JOIN address AS a ON c.address_id = a.address_id
#     INNER JOIN city ON a.city_id = city.city_id
#     INNER JOIN country ON city.country_id = country.country_id
#     GROUP BY country.country
# )
# SELECT country,
#        total_sales,
#        ROUND(((total_sales / SUM(total_sales) OVER ()) * 100),2) AS sales_percentage
# FROM country_sales
# ORDER BY total_sales DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 10 rows affected.
# [('India', Decimal('6034.78'), Decimal('9.84')),
#  ('China', Decimal('5251.03'), Decimal('8.56')),
#  ('United States', Decimal('3685.31'), Decimal('6.01')),
#  ('Japan', Decimal('3122.51'), Decimal('5.09')),
#  ('Mexico', Decimal('2984.82'), Decimal('4.87')),
#  ('Brazil', Decimal('2919.19'), Decimal('4.76')),
#  ('Russian Federation', Decimal('2765.62'), Decimal('4.51')),
#  ('Philippines', Decimal('2219.70'), Decimal('3.62')),
#  ('Turkey', Decimal('1498.49'), Decimal('2.44')),
#  ('Indonesia', Decimal('1352.69'), Decimal('2.21'))]

# %% [markdown]
# The data demonstrates a compelling relationship between customer loyalty and the top 10 countries, which collectively contribute to 51.91% of the total sales. This highlights the vital role of maintaining customer loyalty in these regions to drive significant revenue. Notably, the top 3 countries alone account for 24.41% of the total sales, reflecting their substantial impact on overall performance, representing nearly a quarter of the entire revenue.
#
# Analyzing the customer count in these three countries further strengthens the significance of this segment, emphasizing the need to focus on nurturing these loyal customers to ensure sustained growth and profitability. Additionally, this data suggests that implementing targeted loyalty programs in these top-performing countries could yield substantial returns and foster a stronger market presence.

# %% [markdown]
# # Films Analysis

# %% [markdown]
# ## 1. How many unique films?

# %%
# %%sql
# SELECT COUNT(DISTINCT(film_id)) AS total_distinct_film
# FROM film;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(1000,)]

# %% [markdown]
# The dataset contains a diverse collection of 1000 unique films. In the upcoming sessions, we will conduct an in-depth analysis of this film portfolio to gain valuable insights into the DVD rental market.

# %% [markdown]
# ## 2. Which film categories have the highest number of rentals? What is the percentage of total rental counts contributed by each category?

# %%
# %%sql
# WITH category_rental_counts AS (
#     SELECT c.name AS category_name, COUNT(r.rental_id) AS rental_count
#     FROM category AS c
#     INNER JOIN film_category fc ON c.category_id = fc.category_id
#     INNER JOIN film AS f ON fc.film_id = f.film_id
#     INNER JOIN inventory AS i ON f.film_id = i.film_id
#     INNER JOIN rental AS r ON i.inventory_id = r.inventory_id
#     INNER JOIN customer AS cu ON r.customer_id = cu.customer_id
#     GROUP BY c.category_id, c.name
# )
# SELECT
#     category_name,
#     rental_count,
#     ROUND(((rental_count * 100.0) / SUM(rental_count) OVER()),2) AS rental_percentage
# FROM category_rental_counts
# ORDER BY rental_count DESC;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 16 rows affected.
# [('Sports', 1179, Decimal('7.35')),
#  ('Animation', 1166, Decimal('7.27')),
#  ('Action', 1112, Decimal('6.93')),
#  ('Sci-Fi', 1101, Decimal('6.86')),
#  ('Family', 1096, Decimal('6.83')),
#  ('Drama', 1060, Decimal('6.61')),
#  ('Documentary', 1050, Decimal('6.54')),
#  ('Foreign', 1033, Decimal('6.44')),
#  ('Games', 969, Decimal('6.04')),
#  ('Children', 945, Decimal('5.89')),
#  ('Comedy', 941, Decimal('5.87')),
#  ('New', 940, Decimal('5.86')),
#  ('Classics', 939, Decimal('5.85')),
#  ('Horror', 846, Decimal('5.27')),
#  ('Travel', 837, Decimal('5.22')),
#  ('Music', 830, Decimal('5.17'))]

# %% [markdown]
# Sports, Animation, and Action stand out as the top three film categories, collectively accounting for 21.55% of the total rentals. This information indicates an opportunity for the store to expand its offerings in these categories or strategically position them for higher visibility.
#
# Furthermore, in our customer analysis, we have observed that frequent and long-term customers tend to generate higher revenue. Therefore, we will also explore the total rental duration across different film categories to gain further insights.

# %% [markdown]
# ## 3. Which film categories have the longest total rental duration? What is the percentage of total rental duration contributed by each category?

# %%
# %%sql
# WITH category_total_rental_duration AS (
#     SELECT c.name AS category_name, SUM(EXTRACT(DAY FROM r.return_date - r.rental_date)) AS total_rental_duration
#     FROM category AS c
#     INNER JOIN film_category fc ON c.category_id = fc.category_id
#     INNER JOIN film AS f ON fc.film_id = f.film_id
#     INNER JOIN inventory AS i ON f.film_id = i.film_id
#     INNER JOIN rental AS r ON i.inventory_id = r.inventory_id
#     GROUP BY c.category_id, c.name
# )
# SELECT
#     category_name,
#     total_rental_duration,
#     ROUND(((total_rental_duration * 100.0) / SUM(total_rental_duration) OVER()),2) AS rental_duration_percentage
# FROM category_total_rental_duration
# ORDER BY total_rental_duration DESC;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 16 rows affected.
# [('Sports', Decimal('5473'), Decimal('7.62')),
#  ('Animation', Decimal('5012'), Decimal('6.98')),
#  ('Sci-Fi', Decimal('5007'), Decimal('6.97')),
#  ('Action', Decimal('4950'), Decimal('6.90')),
#  ('Family', Decimal('4915'), Decimal('6.85')),
#  ('Documentary', Decimal('4747'), Decimal('6.61')),
#  ('Foreign', Decimal('4612'), Decimal('6.42')),
#  ('Drama', Decimal('4604'), Decimal('6.41')),
#  ('Games', Decimal('4478'), Decimal('6.24')),
#  ('Comedy', Decimal('4346'), Decimal('6.05')),
#  ('New', Decimal('4200'), Decimal('5.85')),
#  ('Children', Decimal('4171'), Decimal('5.81')),
#  ('Classics', Decimal('4131'), Decimal('5.75')),
#  ('Horror', Decimal('3805'), Decimal('5.30')),
#  ('Music', Decimal('3740'), Decimal('5.21')),
#  ('Travel', Decimal('3595'), Decimal('5.01'))]

# %% [markdown]
# Sports, Animation, and Sci-Fi rank as the top three film categories based on the total rental duration, constituting a combined 21.57% of the overall rental duration. In our next analysis, we will conduct a similar examination focused on total sales to identify the target film category for further insights.

# %% [markdown]
# ## 4. Which film categories have the highest sale? What is the percentage of total sales contributed by each category?

# %%
# %%sql
# WITH category_total_sales AS (
#     SELECT c.name AS category_name, SUM(p.amount) AS total_sales
#     FROM category AS c
#     INNER JOIN film_category fc ON c.category_id = fc.category_id
#     INNER JOIN film AS f ON fc.film_id = f.film_id
#     INNER JOIN inventory AS i ON f.film_id = i.film_id
#     INNER JOIN rental AS r ON i.inventory_id = r.inventory_id
#     INNER JOIN customer AS cu ON r.customer_id = cu.customer_id
#     INNER JOIN payment AS p ON r.rental_id = p.rental_id
#     GROUP BY c.category_id, c.name
# )
# SELECT
#     category_name,
#     total_sales,
#     ROUND(((total_sales * 100.0) / SUM(total_sales) OVER()),2) AS sales_percentage
# FROM category_total_sales
# ORDER BY total_sales DESC;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 16 rows affected.
# [('Sports', Decimal('4892.19'), Decimal('7.98')),
#  ('Sci-Fi', Decimal('4336.01'), Decimal('7.07')),
#  ('Animation', Decimal('4245.31'), Decimal('6.92')),
#  ('Drama', Decimal('4118.46'), Decimal('6.72')),
#  ('Comedy', Decimal('4002.48'), Decimal('6.53')),
#  ('New', Decimal('3966.38'), Decimal('6.47')),
#  ('Action', Decimal('3951.84'), Decimal('6.45')),
#  ('Foreign', Decimal('3934.47'), Decimal('6.42')),
#  ('Games', Decimal('3922.18'), Decimal('6.40')),
#  ('Family', Decimal('3830.15'), Decimal('6.25')),
#  ('Documentary', Decimal('3749.65'), Decimal('6.12')),
#  ('Horror', Decimal('3401.27'), Decimal('5.55')),
#  ('Classics', Decimal('3353.38'), Decimal('5.47')),
#  ('Children', Decimal('3309.39'), Decimal('5.40')),
#  ('Travel', Decimal('3227.36'), Decimal('5.26')),
#  ('Music', Decimal('3071.52'), Decimal('5.01'))]

# %% [markdown]
# When considering total sales, the film categories Sports, Sci-Fi, and Animation emerge as the top three, contributing to a combined 21.97% of the overall sales. Combining this information with the results from the previous analyses, we recommend targeting the film categories Sports, Animation, Action, and Sci-Fi to attract more customers, particularly frequent and long-term renters. This strategic approach aims to capitalize on the popularity of these genres and foster customer loyalty within the rental service.

# %% [markdown]
# ## 5. What is the top 10 rating films? What is the film categroy associated with these films?

# %%
# %%sql
# SELECT f.film_id, f.title, f.release_year, name AS category_name
# FROM film AS f
# INNER JOIN film_category AS fc ON f.film_id = fc.film_id
# INNER JOIN category AS c ON fc.category_id = c.category_id
# ORDER BY f.rating DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 10 rows affected.
# [(29, 'Antitrust Tomatoes', 2006, 'Action'),
#  (34, 'Arabia Dogma', 2006, 'Horror'),
#  (27, 'Anonymous Human', 2006, 'Sports'),
#  (15, 'Alien Center', 2006, 'Foreign'),
#  (3, 'Adaptation Holes', 2006, 'Documentary'),
#  (31, 'Apache Divine', 2006, 'Family'),
#  (16, 'Alley Evolution', 2006, 'Foreign'),
#  (14, 'Alice Fantasia', 2006, 'Classics'),
#  (10, 'Aladdin Calendar', 2006, 'Sports'),
#  (38, 'Ark Ridgemont', 2006, 'Action')]

# %% [markdown]
# The table above displays the top 10 highest-rated films along with their respective film categories. Interestingly, it is evident that the films with the highest ratings do not necessarily belong to the categories that generate higher revenue or have a higher rental frequency.

# %% [markdown]
# ## 6. Does the sales performance have seasonal trend?

# %%
# %%sql
# SELECT EXTRACT(MONTH FROM r.rental_date) AS rental_month,
#        COUNT(r.rental_id) AS rental_count,
#        SUM(p.amount) AS total_sales
# FROM film AS f
# INNER JOIN inventory AS i ON f.film_id = i.film_id
# INNER JOIN rental AS r ON i.inventory_id = r.inventory_id
# INNER JOIN payment AS p ON r.rental_id = p.rental_id
# GROUP BY rental_month
# ORDER BY total_sales DESC;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 4 rows affected.
# [(Decimal('7'), 6713, Decimal('28377.87')),
#  (Decimal('8'), 5686, Decimal('24070.14')),
#  (Decimal('6'), 2015, Decimal('8349.85')),
#  (Decimal('2'), 182, Decimal('514.18'))]

# %% [markdown]
# The analysis focuses on the rental month to examine seasonal trends, and the results indicate that the majority of rentals are concentrated in the months of June to August and February. This pattern is interesting and suggests that customers may tend to watch more films during the summer months. However, due to the absence of rentals in other months, we are unable to draw definitive conclusions. To validate this observation and gain more comprehensive insights, additional data spanning across all months would be beneficial. Additionally, further investigation into customer preferences and external factors influencing movie-watching habits during these months could provide a more nuanced understanding of the observed seasonal trends.

# %% [markdown]
# ## 7.a. What are the top 10 popular films in India?

# %%
# %%sql
# SELECT f.title, c.name AS category_name, f.rating, l.name AS language, COUNT(r.rental_id) AS rental_count
# FROM category AS c
# INNER JOIN film_category fc ON c.category_id = fc.category_id
# INNER JOIN film AS f ON fc.film_id = f.film_id
# INNER JOIN inventory AS i ON f.film_id = i.film_id
# INNER JOIN rental AS r ON i.inventory_id = r.inventory_id
# INNER JOIN customer AS cu ON r.customer_id = cu.customer_id
# INNER JOIN address AS a ON cu.address_id = a.address_id
# INNER JOIN city ON a.city_id = city.city_id
# INNER JOIN country ON city.country_id = country.country_id
# INNER JOIN language AS l ON f.language_id = l.language_id
# WHERE country = 'India'
# GROUP BY f.title, category_name, f.rating, l.language_id
# ORDER BY rental_count DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 10 rows affected.
# [('Wife Turn', 'Documentary', 'NC-17', 'English             ', 9),
#  ('Innocent Usual', 'Foreign', 'PG-13', 'English             ', 8),
#  ('Sabrina Midnight', 'Children', 'PG', 'English             ', 7),
#  ('Secret Groundhog', 'Documentary', 'PG', 'English             ', 7),
#  ('Fiction Christmas', 'Foreign', 'PG', 'English             ', 7),
#  ('Mockingbird Hollywood', 'Action', 'PG', 'English             ', 6),
#  ('Torque Bound', 'Drama', 'G', 'English             ', 6),
#  ('Army Flintstones', 'Documentary', 'R', 'English             ', 5),
#  ('Brotherhood Blanket', 'Documentary', 'R', 'English             ', 5),
#  ('Harry Idaho', 'Drama', 'PG-13', 'English             ', 5)]

# %% [markdown]
# The table indicates that Indian audiences favor documentaries.

# %% [markdown]
# ## 7.b. What are the top 10 popular films in China?

# %%
# %%sql
# SELECT f.title, c.name AS category_name, f.rating, l.name AS language, COUNT(r.rental_id) AS rental_count
# FROM category AS c
# INNER JOIN film_category fc ON c.category_id = fc.category_id
# INNER JOIN film AS f ON fc.film_id = f.film_id
# INNER JOIN inventory AS i ON f.film_id = i.film_id
# INNER JOIN rental AS r ON i.inventory_id = r.inventory_id
# INNER JOIN customer AS cu ON r.customer_id = cu.customer_id
# INNER JOIN address AS a ON cu.address_id = a.address_id
# INNER JOIN city ON a.city_id = city.city_id
# INNER JOIN country ON city.country_id = country.country_id
# INNER JOIN language AS l ON f.language_id = l.language_id
# WHERE country = 'China'
# GROUP BY f.title, category_name, f.rating, l.language_id
# ORDER BY rental_count DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 10 rows affected.
# [('Story Side', 'Action', 'R', 'English             ', 8),
#  ('Balloon Homeward', 'Music', 'NC-17', 'English             ', 7),
#  ('Packer Madigan', 'Animation', 'PG-13', 'English             ', 7),
#  ('Roses Treasure', 'Sports', 'PG-13', 'English             ', 6),
#  ('Kick Savannah', 'Travel', 'PG-13', 'English             ', 6),
#  ('Enemy Odds', 'Music', 'NC-17', 'English             ', 6),
#  ('Cleopatra Devil', 'New', 'PG-13', 'English             ', 6),
#  ('Hurricane Affair', 'Comedy', 'PG', 'English             ', 6),
#  ('Chill Luck', 'Drama', 'PG', 'English             ', 6),
#  ('Dynamite Tarzan', 'Classics', 'PG-13', 'English             ', 5)]

# %% [markdown]
# Chinese preferences are more diverse, with only one category being repeated in the top 10 popular films in China.

# %% [markdown]
# ## 7.c. What are the top 10 popular films in United States?

# %%
# %%sql
# SELECT f.title, c.name AS category_name, f.rating, l.name AS language, COUNT(r.rental_id) AS rental_count
# FROM category AS c
# INNER JOIN film_category fc ON c.category_id = fc.category_id
# INNER JOIN film AS f ON fc.film_id = f.film_id
# INNER JOIN inventory AS i ON f.film_id = i.film_id
# INNER JOIN rental AS r ON i.inventory_id = r.inventory_id
# INNER JOIN customer AS cu ON r.customer_id = cu.customer_id
# INNER JOIN address AS a ON cu.address_id = a.address_id
# INNER JOIN city ON a.city_id = city.city_id
# INNER JOIN country ON city.country_id = country.country_id
# INNER JOIN language AS l ON f.language_id = l.language_id
# WHERE country = 'United States'
# GROUP BY f.title, category_name, f.rating, l.language_id
# ORDER BY rental_count DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 10 rows affected.
# [('Sleuth Orient', 'Games', 'NC-17', 'English             ', 6),
#  ('Island Exorcist', 'Classics', 'NC-17', 'English             ', 5),
#  ('English Bulworth', 'Sci-Fi', 'PG-13', 'English             ', 5),
#  ('Forward Temple', 'Games', 'NC-17', 'English             ', 5),
#  ('Show Lord', 'Documentary', 'PG-13', 'English             ', 5),
#  ('Hanky October', 'Sci-Fi', 'NC-17', 'English             ', 4),
#  ('Handicap Boondock', 'Action', 'R', 'English             ', 4),
#  ('Frost Head', 'Classics', 'PG', 'English             ', 4),
#  ('Cupboard Sinners', 'Documentary', 'R', 'English             ', 4),
#  ('Boogie Amelie', 'Music', 'R', 'English             ', 4)]

# %% [markdown]
# Lastly, we can observe that Americans have a preference for films in the Games, Classics, Sci-Fi, and Documentary categories.

# %% [markdown]
# The analysis of the top 10 popular films in India, China, and the United States highlights the crucial importance of considering local preferences when planning marketing or customer loyalty campaigns in different countries. It is evident that film preferences can vary significantly across regions, and tailoring strategies to suit specific markets is essential for success.
#
# Additionally, an interesting observation is that all the films in the top 10 sales countries are in English. This finding challenges the assumption that Chinese audiences might prefer films in Mandarin. To gain further insights, the distribution of films in different languages will be presented in the next session.

# %% [markdown]
# ## 8. What is the breakdown of films according to different languages?

# %%
# %%sql
# SELECT DISTINCT(name) AS languages
# FROM language
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 6 rows affected.
# [('English             ',),
#  ('French              ',),
#  ('German              ',),
#  ('Mandarin            ',),
#  ('Japanese            ',),
#  ('Italian             ',)]

# %% [markdown]
# The dataset contains movies in 6 unique languages. To conduct a language analysis of films, we will compute the distribution of films based on languages.

# %%
# %%sql
# SELECT DISTINCT(l.name) AS languages, COUNT(DISTINCT(film_id)) AS count_movies
# FROM language AS l
# INNER JOIN film AS f ON l.language_id = f.language_id
# GROUP BY languages
# ORDER BY count_movies DESC;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [('English             ', 1000)]

# %% [markdown]
# Surprisingly, all of these films are in the English language. This means that there are no movies in the dataset that are in languages other than English. As a result, the count of movies for each language, besides English, is zero. To conduct a language analysis of films, we would need movies in different languages to be present in the dataset.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The comprehensive analysis of customer behavior and film preferences offers valuable insights for optimizing the DVD rental service. The identification of the top 10 countries, such as India, China, and the United States, as significant contributors to total sales underscores the importance of tailoring marketing efforts and customer loyalty programs in these key markets.
#
# By focusing on the most popular film categories, namely "Sports," "Animation," "Action," and "Sci-Fi," the rental service can attract and retain more customers, particularly frequent and long-term renters. These genres have shown to generate substantial rental counts and total sales, making them crucial areas to prioritize for growth and revenue maximization.
#
# Furthermore, it is evident that frequent and long-term customers tend to generate higher revenue. As a result, implementing targeted customer loyalty programs aimed at this group can yield fruitful results. Additionally, efforts should be made to convert other customer segments into this category through personalized offerings and incentives.
#
# Overall, leveraging these insights and implementing data-driven strategies can enhance customer satisfaction, drive revenue growth, and position the rental service competitively in the ever-evolving DVD rental market. The focus on understanding local preferences and behavior ensures a personalized film selection and fosters lasting customer relationships, driving long-term success for the business.
